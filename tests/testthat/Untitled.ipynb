# %%
data = Import["sampleData/J20S400.csv", "CSV"];

# %%
data = data[[All, 2 ;;]];
data = data[[2 ;; All, All]];
data = ToExpression[data];
data = data /. -99 -> Missing[];

# %%
rowMeans = Mean[DeleteMissing[#]] & /@ data;

# %%
RM = Mean[rowMeans]
# Out:
# 934717
# -------
# 1368000

# %%
N[rowMeans]
# Out:
# {0.55, 0.75, 0.85, 0.842105, 0.6, 0.75, 0.368421, 0.95, 0.85, 0.6, 0.8, 0.842105,
#
# >   0.473684, 0.8, 0.7, 0.95, 0.555556, 0.45, 0.45, 0.6, 0.65, 0.7, 0.5, 0.842105,
#
# >   0.789474, 0.789474, 0.75, 0.8, 0.7, 0.9, 0.5, 0.526316, 0.95, 0.9, 0.894737, 0.45,
#
# >   0.9, 0.95, 0.7, 0.85, 0.8, 0.85, 0.6, 0.7, 0.85, 0.444444, 0.777778, 0.7, 0.5, 0.95,
#
# >   0.7, 0.7, 0.85, 0.85, 0.9, 0.85, 0.75, 0.65, 0.6, 0.35, 0.7, 0.722222, 0.7, 0.85,
#
# >   0.105263, 0.7, 0.7, 0.45, 0.75, 0.7, 0.421053, 0.947368, 0.75, 0.4, 0.55, 0.8,
#
# >   0.947368, 0.8, 0.684211, 0.85, 0.368421, 0.4, 0.95, 0.85, 0.35, 0.7, 0.55, 0.55,
#
# >   0.65, 0.6, 0.8, 0.15, 0.55, 0.4, 0.842105, 0.4, 0.473684, 0.65, 0.555556, 1., 0.8,
#
# >   0.736842, 0.944444, 0.9, 0.75, 0.5, 0.85, 0.894737, 0.8, 0.25, 0.75, 0.25, 0.85,
#
# >   0.85, 0.65, 0.35, 0.45, 0.55, 0.85, 0.45, 0.9, 0.789474, 0.263158, 0.8, 0.65, 0.9,
#
# >   0.75, 0.75, 0.85, 0.95, 0.842105, 0.45, 0.8, 0.85, 0.65, 0.8, 0.8, 0.65, 0.7,
#
# ...
